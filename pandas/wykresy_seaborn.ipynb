# %%
#https://www.youtube.com/watch?v=6GUZXDef2U0
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dff = pd.read_csv('.\pandas_Countries.csv')

# %%
dff
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area sq. mi. Pop. Density sq. mi. Coastline coast/area ratio  \
# ...

# %%
dff.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area sq. mi.',
#        'Pop. Density sq. mi.', 'Coastline coast/area ratio', 'Net migration',
#        'Infant mortality per 1000 births', 'GDP', 'Literacy',
#        'Phones per 1000', 'Climate', 'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
df = dff[['Country', 'Region', 'Population','Area sq. mi.', 'Net migration','Infant mortality per 1000 births', 'GDP', 'Literacy', 'Phones per 1000']].copy()

# %%
df.rename(columns={'GDP': 'GDP per capita'}, inplace=True)

# %%
df['Population'] = df['Population']/1000000

# %%
df['GDP [mld dolars]'] = df['GDP per capita']*df['Population']/1000

# %%
df.head(10)
# Out:
#               Country                               Region  Population  \
# 0        Afghanistan         ASIA (EX. NEAR EAST)            31.056997
# 1            Albania   EASTERN EUROPE                         3.581655
# 2            Algeria   NORTHERN AFRICA                       32.930091
# 3     American Samoa   OCEANIA                                0.057794
# 4            Andorra   WESTERN EUROPE                         0.071201
# 5             Angola   SUB-SAHARAN AFRICA                    12.127071
# 6           Anguilla               LATIN AMER. & CARIB        0.013477
# 7  Antigua & Barbuda               LATIN AMER. & CARIB        0.069108
# 8          Argentina               LATIN AMER. & CARIB       39.921833
# 9            Armenia                  C.W. OF IND. STATES     2.976372
#
#    Area sq. mi. Net migration Infant mortality per 1000 births  \
# 0        647500         23,06                           163,07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           227 non-null    object
#  1   Region                            227 non-null    object
#  2   Population                        227 non-null    float64
#  3   Area sq. mi.                      227 non-null    int64
#  4   Net migration                     224 non-null    object
#  5   Infant mortality per 1000 births  224 non-null    object
#  6   GDP per capita                    226 non-null    float64
#  7   Literacy                          209 non-null    object
#  8   Phones per 1000                   223 non-null    object
#  9   GDP [mld dolars]                  226 non-null    float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 17.9+ KB

# %%
df['Net migration'] = df['Net migration'].str.replace(',', '.')

# %%
df['Infant mortality per 1000 births'] = df['Infant mortality per 1000 births'].str.replace(',', '.')

# %%
df['Net migration'] = df['Net migration'].str.replace(',', '.')

# %%
df['Phones per 1000'] = df['Phones per 1000'].str.replace(',', '.')

# %%
df['Literacy'] = df['Literacy'].str.replace(',', '.')

# %%
df[['Net migration','Infant mortality per 1000 births','Literacy', 'Phones per 1000']] = df[['Net migration','Infant mortality per 1000 births','Literacy', 'Phones per 1000']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           227 non-null    object
#  1   Region                            227 non-null    object
#  2   Population                        227 non-null    float64
#  3   Area sq. mi.                      227 non-null    int64
#  4   Net migration                     224 non-null    float64
#  5   Infant mortality per 1000 births  224 non-null    float64
#  6   GDP per capita                    226 non-null    float64
#  7   Literacy                          209 non-null    float64
#  8   Phones per 1000                   223 non-null    float64
#  9   GDP [mld dolars]                  226 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 17.9+ KB

# %%
df.describe()
# Out:
#         Population  Area sq. mi.  Net migration  \
# count   227.000000  2.270000e+02     224.000000
# mean     28.740284  5.982270e+05       0.038125
# std     117.891327  1.790282e+06       4.889269
# min       0.007026  2.000000e+00     -20.990000
# 25%       0.437624  4.647500e+03      -0.927500
# 50%       4.786994  8.660000e+04       0.000000
# 75%      17.497772  4.418110e+05       0.997500
# max    1313.973713  1.707520e+07      23.060000
#
#        Infant mortality per 1000 births  GDP per capita    Literacy  \
# count                        224.000000      226.000000  209.000000
# mean                          35.506964     9689.823009   82.838278
# std                           35.389899    10049.138513   19.722173
# min                            2.290000      500.000000   17.600000
# 25%                            8.150000     1900.000000   70.600000
# 50%                           21.000000     5550.000000   92.500000
# ...

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# ### Distribution Plot:

# %%
sns.distplot(crash_df['not_distracted'])
# Out:
# C:\ProgramData\Anaconda3\envs\data_e\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted', ylabel='Density'>

# %%
sns.distplot(crash_df['not_distracted'], kde=False)
# Out:
# C:\ProgramData\Anaconda3\envs\data_e\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted'>

# %%
sns.distplot(crash_df['not_distracted'], kde=False, bins=25)
# Out:
# <AxesSubplot:xlabel='not_distracted'>

# %% [markdown]
# ### Join Plot:

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='kde')

# %% [markdown]
# ###  KDE Plot:

# %%
sns.kdeplot(crash_df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# ### Pair Plots

# %%
sns.pairplot(crash_df)

# %%
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips_df, hue='sex', palette='Blues')

# %% [markdown]
# ###  Rug Plot:

# %%
sns.rugplot(tips_df['tip']) # pokazuje ktore wartosci wystepuja najczesciej
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# ### Styling

# %%
sns.set_style('darkgrid') # ciemne tlo, linie
plt.figure(figsize=(8,4))  # wymiary wykresu poniżej
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('dark') # ciemne tło
sns.set_context('paper', font_scale=1.4) # paper = male kropki
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('whitegrid')
sns.set_context('talk') # duze kropki i napisy, wieksza czytelnosc
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('white')
sns.set_context('poster')  # giga kropki i napisy
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('ticks')
plt.figure(figsize=(8,4))  # wymiary wykresu poniżej
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_context('paper')
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')
sns.despine(left=True, bottom=True) # usuniecie osi lewej i dolnej

# %% [markdown]
# ### Bar Plots:

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.median)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.var)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.cov)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### Count Plot:

# %%
sns.countplot(x='sex', data=tips_df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ### Box Plot:

# %%
sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex') 
# kobiety wiecej wydaja w weekendy xD
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Violin Plot:

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df, hue='sex', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Strip Plot:

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex')
plt.legend(loc=0)

# %%
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex', dodge=True)
plt.legend(loc=1) # loc = 2 prawy dolny rog, loc=3 to lewy dolny rog

# %% [markdown]
# ### Swarm Plot:

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips_df, palette='magma') 
# palety dostepne w dokumentacji matplotlib
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Heatmaps

# %%
crash_df.head()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
crash_mx = crash_df.corr() # korelacja - ustawienie kolumn na miejscu wierszy i podanie wspolczynnika korelacji
crash_mx
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

sns.heatmap(crash_mx, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = flights.pivot_table(index='month', columns='year', values='passengers')
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flights, cmap='Blues')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(flights, cmap='Blues', linecolor='white', linewidth=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ### Cluster Map

# %%
sns.clustermap(flights,cmap='Blues', standard_scale=1)

# %% [markdown]
# ### PairGrid:

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_g = sns.PairGrid(iris, hue='species')
iris_g.map(plt.scatter)

# %%
iris_g = sns.PairGrid(iris, hue='species')
iris_g.map_diag(plt.hist)

# %%
iris_g = sns.PairGrid(iris, hue='species')
iris_g.map_offdiag(plt.scatter)

# %%
iris_g = sns.PairGrid(iris, hue='species')
iris_g.map_lower(sns.kdeplot)

# %%
iris_g = sns.PairGrid(iris, hue='species', 
                      x_vars=['sepal_length','sepal_width'],
                      y_vars=['petal_length','petal_width'])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# ### Facet Grid:

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')
tips_fg.map(plt.hist, 'total_bill', bins=8)

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', hue='smoker', height=4, aspect=1.3)
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', hue='smoker', height=4, aspect=1.3,
                       col_order=['Dinner', 'Lunch'], palette='Set1')
tips_fg.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')

# %%
kws = dict(s=50, linewidth=.5, edgecolor='w')
tips_fg = sns.FacetGrid(tips_df, col='sex', hue='smoker', height=4, aspect=1.3,
                       hue_order=['Yes', 'No'],
                       hue_kws=dict(marker=['^', 'v']))
tips_fg.map(plt.scatter,  'total_bill', 'tip', **kws)

# %%
att_df = sns.load_dataset('attention')
att_df
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# ...

# %%
att_fg = sns.FacetGrid(att_df, col='subject', col_wrap=5, height=1.5)
att_fg.map(plt.plot, 'solutions', 'score', marker='.')

# %% [markdown]
# ### Regression Plots:

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips_df, markers=['o', '^'],
          scatter_kws={'s':100, 'linewidth':0.5, 'edgecolor':'w'})

# %%
sns.lmplot(x='total_bill', y='tip', col='sex', row='time', data=tips_df,
          height = 6, aspect=0.65)
